# %%
import sys
from pathlib import Path

sys.path.append(str(Path("../pipeline").resolve()))

from prepare_bcg_data import run_pipeline

# %%
updated_bcg_info = run_pipeline()
updated_bcg_info
# Out:
# INFO: Found 29 FITS files.
# INFO: Processing 1/29: member.0099-00913_revised.fits
# INFO: Processing 2/29: member.COMBO-17_48654_revised.fits
# INFO: Processing 3/29: member.D32064369_sci.spw23.cube.I.pbcor.fits
# INFO: Processing 4/29: member.OzDES-DR2_04572_revised.fits
# INFO: Processing 5/29: member.OzDES-DR2_04586_revised.fits
# INFO: Processing 6/29: member.SVA1_COADD-2938085330_revised.fits
# INFO: Processing 7/29: member.SVA1_COADD-2938301050_revised.fits
# INFO: Processing 8/29: member.SVA1_COADD-2938633040_revised.fits
# INFO: Processing 9/29: member.SVA1_COADD-2938639684_100kms.fits
# INFO: Processing 10/29: member.SVA1_COADD-2938863443_revised.fits
# INFO: Processing 11/29: member.SVA1_COADD-2938969684_revised.fits
# INFO: Processing 12/29: member.SVA1_COADD-2939015646_revised.fits
# INFO: Processing 13/29: member.SVA1_COADD-2939717201_revised.fits
# INFO: Processing 14/29: member.SVA1_COADD-2939719204_50kms.fits
# ...

# %%
updated_bcg_info[
    [
        "ID",
        "z",
        "BMAJ (arcsec)",
        "BMIN (arcsec)",
        "BPA (deg)"
    ]
]
# Out:
#                  ID         z  BMAJ (arcsec)  BMIN (arcsec)  BPA (deg)
# 0   SpARCS0035-4303  0.838361       2.612341       2.123972  79.323898
# 1   SpARCS0332-2740  0.740000       3.711323       1.905093 -83.066269
# 2   SpARCS0331-2732  0.763930       2.032111       1.612080 -82.527611
# 3   SpARCS0026-4300  0.547610       2.337477       1.858479  84.064537
# 4   SpARCS0036-4414  0.838190       2.638438       2.300144  77.217201
# 5   SpARCS0221-0550  0.745230       2.812235       2.091939  72.345039
# 6   SpARCS0220-0600  0.654020       2.444299       1.958387  83.677002
# 7   SpARCS0219-0505  0.518760       3.059742       1.831284 -79.743813
# 8   SpARCS0218-0500  1.093360       2.832822       1.521083 -73.668098
# 9   SpARCS0222-0421  0.827430       3.168015       2.250434 -83.325760
# 10  SpARCS0225-0447  0.832980       2.924096       2.255986  80.096802
# 11  SpARCS0225-0428  1.011660       2.332865       1.532758 -64.253014
# ...
